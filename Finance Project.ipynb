# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf

# %matplotlib inline

# %%
rt=datetime.datetime(2006,1,1)
end=datetime.datetime(2016,1,1)

# %%
BAC=data.DataReader("BAC","yahoo",start,end)
C=data.DataReader("C",'yahoo',start,end)

GS=data.DataReader("GS",'yahoo',start,end)

JPM=data.DataReader("JPM",'yahoo',start,end)
MS=data.DataReader("MS",'yahoo',start,end)
WFC=data.DataReader("WFC",'yahoo',start,end)

# %%
MS
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-01-03  58.490002  56.740002  57.169998  58.310001  5377000.0  37.758644
# 2006-01-04  59.279999  58.349998  58.700001  58.349998  7977800.0  37.784546
# 2006-01-05  58.590000  58.020000  58.549999  58.509998  5778000.0  37.888165
# 2006-01-06  58.849998  58.049999  58.770000  58.570000  6889800.0  37.927017
# 2006-01-09  59.290001  58.619999  58.630001  59.189999  4144500.0  38.328484
# ...               ...        ...        ...        ...        ...        ...
# 2015-12-24  32.709999  32.439999  32.570000  32.480000  2798200.0  29.372513
# 2015-12-28  32.360001  31.950001  32.360001  32.169998  5420300.0  29.092171
# 2015-12-29  32.700001  32.330002  32.439999  32.549999  6388200.0  29.435816
# 2015-12-30  32.650002  32.200001  32.500000  32.230000  5057200.0  29.146427
# 2015-12-31  32.299999  31.770000  31.910000  31.809999  8154300.0  28.766611
#
# [2517 rows x 6 columns]

# %%
tickers=['BAC','C','GS','JPM','MS','WFC']

# %%
bank_stocks=pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)
bank_stocks
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  35.298687
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  34.923801
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  34.968796
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  34.916302
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  34.938789
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.969635
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.840177
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.978883
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.766198
# ...

# %%
bank_stocks.columns.names=['Bank Ticker','Stock Info']
bank_stocks.head(5)
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   35.298687  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   34.923801  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   34.968796  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %%
for tick in tickers:
    print(tick,bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.900001525878906
# C 564.0999755859375
# GS 247.9199981689453
# JPM 70.08000183105469
# MS 89.30000305175781
# WFC 58.52000045776367

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
returns=pd.DataFrame()

# %%
for tick in tickers:
    returns[tick + ' Return']= bank_stocks[tick]['Close'].pct_change()

# %%
returns
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158
# ...                ...       ...        ...         ...        ...         ...
# 2015-12-24   -0.004037  0.001520  -0.002624   -0.001948  -0.003681   -0.003997
# 2015-12-28   -0.008107 -0.006261  -0.004658   -0.003303  -0.009544   -0.002554
# 2015-12-29    0.008757  0.011455   0.010516    0.010395   0.011812    0.011156
# 2015-12-30   -0.013310 -0.012835  -0.008282   -0.007157  -0.009831   -0.007235
# 2015-12-31   -0.012903 -0.010516  -0.009780   -0.008410  -0.013031   -0.009656
#
# ...

# %%
sns.pairplot(returns[1:])

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'],color='g',bins=50)
plt.grid()

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick,figsize=(15,8))
plt.legend()

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot(figsize=(15,8))

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot(figsize=(15,8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-6c4b5dc3f5bd> in <module>
# ----> 1 bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot(figsize=(15,8))
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
# moving average

# %%
plt.figure(figsize=(15,8))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 days moving-avg')
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC Close')
plt.legend()
plt.grid()

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1, level='Stock Info').corr(),annot=True)

# %%
sns.clustermap(bank_stocks.xs(key='Close',axis=1, level='Stock Info').corr(),annot=True)

# %%
plt.figure(figsize=(20,8))
bac15=BAC[['Open','High','Low','Close']].loc['2015-01-01':'2016-01-01']
bac15.iplot(kind='candle')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-104-abb1d276fa84> in <module>
#       1 plt.figure(figsize=(20,8))
#       2 bac15=BAC[['Open','High','Low','Close']].loc['2015-01-01':'2016-01-01']
# ----> 3 bac15.iplot(kind='candle')
#
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
# ...
